# %% [markdown]
# # Geocoding Toa Payoh's 2022 Resale Flat Data

# %% [markdown]
# ### Author: Kok Jim Meng

# %% [markdown]
# The output of this data processing is for geospatial feature engineering using ArcPy on the sum weighted distance of the block to the NEA's market and food centres. <br>
# Source: <br>
# * NEA Market and Food Centre: https://beta.data.gov.sg/datasets/1389/view
# * HDB Resale Data: https://beta.data.gov.sg/datasets/189/view
# * Convert KML data to SHP: https://mygeodata.cloud/converter/kml-to-shp

# %% [markdown]
# For example, in the buffer or catchment of 400m of each block, how many market and food centres are in the catchment and what's the distance between the block and each of the market/food centre?

# %% [markdown]
# Eg. Blk 126 has a market within 50m and a food centre within 120m. The sum weighted value for Blk 126 will be:

# %% [markdown]
# <center>$1/50 + 1/120 = 0.028$</center>

# %% [markdown]
# ### Note:
# * Data as of 16 Sept 2023
# * Due to high intensification of data, I only select 2022's resale flat data and target at Toa Payoh town
# * Not all blocks' addresses are able to geocode using Nominatim and geopy due to it's open-sourced
# * The data is just a sample data for showing the example of geospatial feature engineering using ArcPy in another notebook

# %%
# Import all the libraries
import glob
import pandas as pd
import numpy as np
import json
import requests
import datetime
from geopy.geocoders import Nominatim

# %%
# Read the data
df = pd.concat([pd.read_csv(f, parse_dates=['month']) for f in glob.glob("../Data/raw/*.csv")],
               ignore_index=True)
df.head()
# Out:
#        month        town flat_type block        street_name storey_range  \
# 0 2015-01-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1 2015-01-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2 2015-01-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3 2015-01-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4 2015-01-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date remaining_lease  \
# 0            60.0        Improved                 1986              70
# 1            68.0  New Generation                 1981              65
# 2            69.0  New Generation                 1980              64
# 3            68.0  New Generation                 1979              63
# 4            68.0  New Generation                 1980              64
#
#    resale_price
# 0      255000.0
# 1      275000.0
# 2      285000.0
# 3      290000.0
# 4      290000.0

# %%
# Get the year
df["year"] = df["month"].dt.year
df
# Out:
#             month        town  flat_type block        street_name  \
# 0      2015-01-01  ANG MO KIO     3 ROOM   174   ANG MO KIO AVE 4
# 1      2015-01-01  ANG MO KIO     3 ROOM   541  ANG MO KIO AVE 10
# 2      2015-01-01  ANG MO KIO     3 ROOM   163   ANG MO KIO AVE 4
# 3      2015-01-01  ANG MO KIO     3 ROOM   446  ANG MO KIO AVE 10
# 4      2015-01-01  ANG MO KIO     3 ROOM   557  ANG MO KIO AVE 10
# ...           ...         ...        ...   ...                ...
# 198986 2023-09-01      YISHUN     5 ROOM  511B       YISHUN ST 51
# 198987 2023-09-01      YISHUN     5 ROOM  504D       YISHUN ST 51
# 198988 2023-09-01      YISHUN  EXECUTIVE   392       YISHUN AVE 6
# 198989 2023-09-01      YISHUN  EXECUTIVE   355     YISHUN RING RD
# 198990 2023-09-01      YISHUN  EXECUTIVE   359     YISHUN RING RD
#
#        storey_range  floor_area_sqm      flat_model  lease_commence_date  \
# 0          07 TO 09            60.0        Improved                 1986
# 1          01 TO 03            68.0  New Generation                 1981
# 2          01 TO 03            69.0  New Generation                 1980
# 3          01 TO 03            68.0  New Generation                 1979
# 4          07 TO 09            68.0  New Generation                 1980
# ...             ...             ...             ...                  ...
# 198986     04 TO 06           113.0        Improved                 2017
# 198987     07 TO 09           112.0        Improved                 2016
# 198988     07 TO 09           142.0       Apartment                 1988
# 198989     04 TO 06           150.0      Maisonette                 1988
# 198990     04 TO 06           146.0      Maisonette                 1988
#
#            remaining_lease  resale_price  year
# 0                       70      255000.0  2015
# 1                       65      275000.0  2015
# 2                       64      285000.0  2015
# 3                       63      290000.0  2015
# 4                       64      290000.0  2015
# ...                    ...           ...   ...
# 198986            93 years      620000.0  2023
# 198987  91 years 07 months      685000.0  2023
# 198988  63 years 09 months      740000.0  2023
# 198989  64 years 03 months      875000.0  2023
# 198990  63 years 11 months      600000.0  2023
#
# [198991 rows x 12 columns]

# %%
# Filter to extract 2022's resale HDB blocks
resale_df_2022 = df[df["year"]==2022]
resale_df_2022
# Out:
#             month        town  flat_type block        street_name  \
# 153829 2022-01-01  ANG MO KIO     2 ROOM   323   ANG MO KIO AVE 3
# 153830 2022-01-01  ANG MO KIO     3 ROOM   320   ANG MO KIO AVE 1
# 153831 2022-01-01  ANG MO KIO     3 ROOM   225   ANG MO KIO AVE 1
# 153832 2022-01-01  ANG MO KIO     3 ROOM   331   ANG MO KIO AVE 1
# 153833 2022-01-01  ANG MO KIO     3 ROOM   534  ANG MO KIO AVE 10
# ...           ...         ...        ...   ...                ...
# 180544 2022-12-01      YISHUN  EXECUTIVE   355     YISHUN RING RD
# 180545 2022-12-01      YISHUN  EXECUTIVE   643       YISHUN ST 61
# 180546 2022-12-01      YISHUN  EXECUTIVE   643       YISHUN ST 61
# 180547 2022-12-01      YISHUN  EXECUTIVE   606       YISHUN ST 61
# 180548 2022-12-01      YISHUN  EXECUTIVE   606       YISHUN ST 61
#
#        storey_range  floor_area_sqm      flat_model  lease_commence_date  \
# 153829     07 TO 09            44.0        Improved                 1977
# 153830     07 TO 09            73.0  New Generation                 1977
# 153831     07 TO 09            67.0  New Generation                 1978
# 153832     07 TO 09            68.0  New Generation                 1981
# 153833     07 TO 09            82.0  New Generation                 1980
# ...             ...             ...             ...                  ...
# 180544     07 TO 09           146.0      Maisonette                 1988
# 180545     07 TO 09           142.0       Apartment                 1987
# 180546     07 TO 09           142.0       Apartment                 1987
# 180547     10 TO 12           146.0      Maisonette                 1987
# 180548     04 TO 06           142.0       Apartment                 1987
#
#            remaining_lease  resale_price  year
# 153829  54 years 05 months      245000.0  2022
# 153830  54 years 05 months      358000.0  2022
# 153831   55 years 01 month      355000.0  2022
# 153832            58 years      338000.0  2022
# 153833  57 years 02 months      420000.0  2022
# ...                    ...           ...   ...
# 180544            65 years      845000.0  2022
# 180545  63 years 10 months      782000.0  2022
# 180546  63 years 10 months      770888.0  2022
# 180547            64 years      788000.0  2022
# 180548            64 years      740000.0  2022
#
# [26720 rows x 12 columns]

# %%
# Filter to get Toa Payoh's
tpy_resale_df_2022 = resale_df_2022[resale_df_2022["town"]=="TOA PAYOH"]
tpy_resale_df_2022
# Out:
#             month       town  flat_type block       street_name storey_range  \
# 155901 2022-01-01  TOA PAYOH     3 ROOM   126   LOR 1 TOA PAYOH     16 TO 18
# 155902 2022-01-01  TOA PAYOH     3 ROOM   157   LOR 1 TOA PAYOH     04 TO 06
# 155903 2022-01-01  TOA PAYOH     3 ROOM   173   LOR 1 TOA PAYOH     10 TO 12
# 155904 2022-01-01  TOA PAYOH     3 ROOM   114   LOR 1 TOA PAYOH     01 TO 03
# 155905 2022-01-01  TOA PAYOH     3 ROOM   158   LOR 1 TOA PAYOH     04 TO 06
# ...           ...        ...        ...   ...               ...          ...
# 180183 2022-12-01  TOA PAYOH     5 ROOM   250     KIM KEAT LINK     07 TO 09
# 180184 2022-12-01  TOA PAYOH     5 ROOM  139B  LOR 1A TOA PAYOH     34 TO 36
# 180185 2022-12-01  TOA PAYOH     5 ROOM    82   LOR 4 TOA PAYOH     01 TO 03
# 180186 2022-12-01  TOA PAYOH     5 ROOM   229   LOR 8 TOA PAYOH     04 TO 06
# 180187 2022-12-01  TOA PAYOH  EXECUTIVE  101B   LOR 2 TOA PAYOH     01 TO 03
#
#         floor_area_sqm flat_model  lease_commence_date     remaining_lease  \
# 155901            67.0   Improved                 1970   47 years 01 month
# 155902            67.0   Improved                 1971  48 years 07 months
# 155903            66.0   Improved                 1972  49 years 07 months
# 155904            65.0   Improved                 1967  44 years 06 months
# 155905            65.0   Improved                 1972   49 years 01 month
# ...                ...        ...                  ...                 ...
# 180183           128.0   Improved                 1989  65 years 02 months
# 180184           114.0       DBSS                 2012  88 years 06 months
# 180185           122.0   Improved                 1996  72 years 11 months
# 180186           117.0   Standard                 1976  52 years 11 months
# 180187           147.0  Apartment                 1993  69 years 05 months
#
#         resale_price  year
# 155901      338000.0  2022
# 155902      345000.0  2022
# 155903      308000.0  2022
# 155904      300000.0  2022
# 155905      310000.0  2022
# ...              ...   ...
# 180183      738000.0  2022
# 180184     1160000.0  2022
# 180185      830000.0  2022
# 180186      582888.0  2022
# 180187      850000.0  2022
#
# [846 rows x 12 columns]

# %%
# Get the relevant cols
unique_tpy_resale_buildings_2022_df = tpy_resale_df_2022[["block", "street_name", "lease_commence_date"]]
unique_tpy_resale_buildings_2022_df
# Out:
#        block       street_name  lease_commence_date
# 155901   126   LOR 1 TOA PAYOH                 1970
# 155902   157   LOR 1 TOA PAYOH                 1971
# 155903   173   LOR 1 TOA PAYOH                 1972
# 155904   114   LOR 1 TOA PAYOH                 1967
# 155905   158   LOR 1 TOA PAYOH                 1972
# ...      ...               ...                  ...
# 180183   250     KIM KEAT LINK                 1989
# 180184  139B  LOR 1A TOA PAYOH                 2012
# 180185    82   LOR 4 TOA PAYOH                 1996
# 180186   229   LOR 8 TOA PAYOH                 1976
# 180187  101B   LOR 2 TOA PAYOH                 1993
#
# [846 rows x 3 columns]

# %%
# Get the remaining lease of years since 2023
unique_tpy_resale_buildings_2022_df["remaining_lease_since_2023"] = datetime.datetime.now().year - unique_tpy_resale_buildings_2022_df["lease_commence_date"]
unique_tpy_resale_buildings_2022_df
# Out:
# C:\Users\jimme\AppData\Local\Temp\ipykernel_16040\751372457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_tpy_resale_buildings_2022_df["remaining_lease_since_2023"] = datetime.datetime.now().year - unique_tpy_resale_buildings_2022_df["lease_commence_date"]
#        block       street_name  lease_commence_date  \
# 155901   126   LOR 1 TOA PAYOH                 1970
# 155902   157   LOR 1 TOA PAYOH                 1971
# 155903   173   LOR 1 TOA PAYOH                 1972
# 155904   114   LOR 1 TOA PAYOH                 1967
# 155905   158   LOR 1 TOA PAYOH                 1972
# ...      ...               ...                  ...
# 180183   250     KIM KEAT LINK                 1989
# 180184  139B  LOR 1A TOA PAYOH                 2012
# 180185    82   LOR 4 TOA PAYOH                 1996
# 180186   229   LOR 8 TOA PAYOH                 1976
# 180187  101B   LOR 2 TOA PAYOH                 1993
#
#         remaining_lease_since_2023
# 155901                          53
# 155902                          52
# 155903                          51
# 155904                          56
# 155905                          51
# ...                            ...
# 180183                          34
# 180184                          11
# 180185                          27
# 180186                          47
# 180187                          30
#
# [846 rows x 4 columns]

# %%
# Remove the duplicate of blocks
unique_tpy_resale_buildings_2022_df = unique_tpy_resale_buildings_2022_df.drop_duplicates()
unique_tpy_resale_buildings_2022_df
# Out:
#        block         street_name  lease_commence_date  \
# 155901   126     LOR 1 TOA PAYOH                 1970
# 155902   157     LOR 1 TOA PAYOH                 1971
# 155903   173     LOR 1 TOA PAYOH                 1972
# 155904   114     LOR 1 TOA PAYOH                 1967
# 155905   158     LOR 1 TOA PAYOH                 1972
# ...      ...                 ...                  ...
# 175894   131  POTONG PASIR AVE 1                 1984
# 177896   159     LOR 1 TOA PAYOH                 1972
# 177907    94     LOR 4 TOA PAYOH                 1967
# 180154    27      TOA PAYOH EAST                 1971
# 180187  101B     LOR 2 TOA PAYOH                 1993
#
#         remaining_lease_since_2023
# 155901                          53
# 155902                          52
# 155903                          51
# 155904                          56
# 155905                          51
# ...                            ...
# 175894                          39
# 177896                          51
# 177907                          56
# 180154                          52
# 180187                          30
#
# [235 rows x 4 columns]

# %%
# Get the address
unique_tpy_resale_buildings_2022_df["address"] = unique_tpy_resale_buildings_2022_df["block"]
                                                + " "
                                                + unique_tpy_resale_buildings_2022_df["street_name"]
unique_tpy_resale_buildings_2022_df = unique_tpy_resale_buildings_2022_df.reset_index()
unique_tpy_resale_buildings_2022_df
# Out:
# C:\Users\jimme\AppData\Local\Temp\ipykernel_16040\861515259.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_tpy_resale_buildings_2022_df["address"] = unique_tpy_resale_buildings_2022_df["block"] + " " + unique_tpy_resale_buildings_2022_df["street_name"]
#       index block         street_name  lease_commence_date  \
# 0    155901   126     LOR 1 TOA PAYOH                 1970
# 1    155902   157     LOR 1 TOA PAYOH                 1971
# 2    155903   173     LOR 1 TOA PAYOH                 1972
# 3    155904   114     LOR 1 TOA PAYOH                 1967
# 4    155905   158     LOR 1 TOA PAYOH                 1972
# ..      ...   ...                 ...                  ...
# 230  175894   131  POTONG PASIR AVE 1                 1984
# 231  177896   159     LOR 1 TOA PAYOH                 1972
# 232  177907    94     LOR 4 TOA PAYOH                 1967
# 233  180154    27      TOA PAYOH EAST                 1971
# 234  180187  101B     LOR 2 TOA PAYOH                 1993
#
#      remaining_lease_since_2023                 address
# 0                            53     126 LOR 1 TOA PAYOH
# 1                            52     157 LOR 1 TOA PAYOH
# 2                            51     173 LOR 1 TOA PAYOH
# 3                            56     114 LOR 1 TOA PAYOH
# 4                            51     158 LOR 1 TOA PAYOH
# ..                          ...                     ...
# 230                          39  131 POTONG PASIR AVE 1
# 231                          51     159 LOR 1 TOA PAYOH
# 232                          56      94 LOR 4 TOA PAYOH
# 233                          52       27 TOA PAYOH EAST
# 234                          30    101B LOR 2 TOA PAYOH
#
# [235 rows x 6 columns]

# %%
# Remove the extra cols
unique_tpy_resale_buildings_2022_df = unique_tpy_resale_buildings_2022_df.drop(columns=['index',
                                                                                        'block',
                                                                                        'street_name',
                                                                                        'lease_commence_date'])
unique_tpy_resale_buildings_2022_df
# Out:
#      remaining_lease_since_2023                 address
# 0                            53     126 LOR 1 TOA PAYOH
# 1                            52     157 LOR 1 TOA PAYOH
# 2                            51     173 LOR 1 TOA PAYOH
# 3                            56     114 LOR 1 TOA PAYOH
# 4                            51     158 LOR 1 TOA PAYOH
# ..                          ...                     ...
# 230                          39  131 POTONG PASIR AVE 1
# 231                          51     159 LOR 1 TOA PAYOH
# 232                          56      94 LOR 4 TOA PAYOH
# 233                          52       27 TOA PAYOH EAST
# 234                          30    101B LOR 2 TOA PAYOH
#
# [235 rows x 2 columns]

# %%
# Geocoding
geolocator = Nominatim(user_agent="my_app")  # using open street map API
unique_tpy_resale_buildings_2022_df['geocode'] = unique_tpy_resale_buildings_2022_df['address'].apply(geolocator.geocode)

# %%
# Check how's the geocoding has processed
unique_tpy_resale_buildings_2022_df
# Out:
#      remaining_lease_since_2023                 address  \
# 0                            53     126 LOR 1 TOA PAYOH
# 1                            52     157 LOR 1 TOA PAYOH
# 2                            51     173 LOR 1 TOA PAYOH
# 3                            56     114 LOR 1 TOA PAYOH
# 4                            51     158 LOR 1 TOA PAYOH
# ..                          ...                     ...
# 230                          39  131 POTONG PASIR AVE 1
# 231                          51     159 LOR 1 TOA PAYOH
# 232                          56      94 LOR 4 TOA PAYOH
# 233                          52       27 TOA PAYOH EAST
# 234                          30    101B LOR 2 TOA PAYOH
#
#                                                geocode
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 230  (131, Potong Pasir Avenue 1, Toa Payoh, Southe...
# 231                                               None
# 232                                               None
# 233  (27, Toa Payoh East, Toa Payoh, Singapore, Cen...
# 234                                               None
#
# [235 rows x 3 columns]

# %%
# Remove the empty geocoded blocks 😣
unique_tpy_resale_buildings_2022_df = unique_tpy_resale_buildings_2022_df.dropna()
unique_tpy_resale_buildings_2022_df
# Out:
#      remaining_lease_since_2023                 address  \
# 9                            53     116 LOR 2 TOA PAYOH
# 18                           39  101 POTONG PASIR AVE 1
# 19                           39  104 POTONG PASIR AVE 1
# 20                           39  115 POTONG PASIR AVE 1
# 21                           39  140 POTONG PASIR AVE 3
# ..                          ...                     ...
# 226                          35          20 JOO SENG RD
# 227                          39  124 POTONG PASIR AVE 1
# 229                          39  135 POTONG PASIR AVE 3
# 230                          39  131 POTONG PASIR AVE 1
# 233                          52       27 TOA PAYOH EAST
#
#                                                geocode
# 9    (Toa Payoh, Singapore, Central, Singapore, (1....
# 18   (101, Potong Pasir Avenue 1, Market Square, To...
# 19   (104, Potong Pasir Avenue 1, Market Square, To...
# 20   (115, Potong Pasir Avenue 1, Toa Payoh, Southe...
# 21   (140, Potong Pasir Avenue 3, Toa Payoh, Singap...
# ..                                                 ...
# 226  (Joo Seng Road, Tai Seng, Joo Seng, Southeast,...
# 227  (124, Potong Pasir Avenue 1, Market Square, To...
# 229  (135, Potong Pasir Avenue 3, Toa Payoh, Singap...
# 230  (131, Potong Pasir Avenue 1, Toa Payoh, Southe...
# 233  (27, Toa Payoh East, Toa Payoh, Singapore, Cen...
#
# [76 rows x 3 columns]

# %%
# Get the latitude and longitude
unique_tpy_resale_buildings_2022_df['latitude'] = [g.latitude for g in unique_tpy_resale_buildings_2022_df.geocode]
unique_tpy_resale_buildings_2022_df['longitude'] = [g.longitude for g in unique_tpy_resale_buildings_2022_df.geocode]
# Out:
# C:\Users\jimme\AppData\Local\Temp\ipykernel_16040\3925462539.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_tpy_resale_buildings_2022_df['latitude'] = [g.latitude for g in unique_tpy_resale_buildings_2022_df.geocode]
# C:\Users\jimme\AppData\Local\Temp\ipykernel_16040\3925462539.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_tpy_resale_buildings_2022_df['longitude'] = [g.longitude for g in unique_tpy_resale_buildings_2022_df.geocode]

# %%
# Output
unique_tpy_resale_buildings_2022_df
# Out:
#      remaining_lease_since_2023                 address  \
# 9                            53     116 LOR 2 TOA PAYOH
# 18                           39  101 POTONG PASIR AVE 1
# 19                           39  104 POTONG PASIR AVE 1
# 20                           39  115 POTONG PASIR AVE 1
# 21                           39  140 POTONG PASIR AVE 3
# ..                          ...                     ...
# 226                          35          20 JOO SENG RD
# 227                          39  124 POTONG PASIR AVE 1
# 229                          39  135 POTONG PASIR AVE 3
# 230                          39  131 POTONG PASIR AVE 1
# 233                          52       27 TOA PAYOH EAST
#
#                                                geocode  latitude   longitude
# 9    (Toa Payoh, Singapore, Central, Singapore, (1....  1.335391  103.849741
# 18   (101, Potong Pasir Avenue 1, Market Square, To...  1.333029  103.868518
# 19   (104, Potong Pasir Avenue 1, Market Square, To...  1.334356  103.869273
# 20   (115, Potong Pasir Avenue 1, Toa Payoh, Southe...  1.337438  103.862638
# 21   (140, Potong Pasir Avenue 3, Toa Payoh, Singap...  1.333839  103.866940
# ..                                                 ...       ...         ...
# 226  (Joo Seng Road, Tai Seng, Joo Seng, Southeast,...  1.337641  103.882505
# 227  (124, Potong Pasir Avenue 1, Market Square, To...  1.335305  103.865496
# 229  (135, Potong Pasir Avenue 3, Toa Payoh, Singap...  1.334683  103.866851
# 230  (131, Potong Pasir Avenue 1, Toa Payoh, Southe...  1.334365  103.865327
# 233  (27, Toa Payoh East, Toa Payoh, Singapore, Cen...  1.332420  103.856739
#
# [76 rows x 5 columns]

# %%
# Save the output into a file
unique_tpy_resale_buildings_2022_df.to_csv("../Data/processed/unique_tpy_resale_buildings_2022_df.csv",
                                           index=False)
